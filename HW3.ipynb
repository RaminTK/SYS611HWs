# %% [markdown]
# <a href="https://colab.research.google.com/github/RaminTKhameneh/SYS611HWs/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# # 3.1 Simulating π Again
#
# **Part a**

# %%
X = np.random.random(1000)
Y = np.random.random(1000)
Z = []
for i in range(len(X)):
  if np.sqrt(X[i]**2 + Y[i]**2) <= 1 :
    Z.append(4)
  else:
    Z.append(0)
print('list of 10 first X:',X[0:10])
print()
print('list of 10 first Y:',Y[0:10])
print()
print('list of 10 first Z:',Z[0:10])
print(len(Z))
# Out:
# list of 10 first X: [0.06009907 0.5842219  0.64345507 0.77200911 0.80672394 0.00744109
#  0.57983873 0.2916535  0.82218151 0.51199002]
#
# list of 10 first Y: [0.5559338  0.85868053 0.85090595 0.52525996 0.28940701 0.57976813
#  0.7440025  0.02796167 0.97312377 0.85994739]
#
# list of 10 first Z: [4, 0, 0, 4, 4, 4, 4, 4, 0, 0]
# 1000

# %% [markdown]
# Part b

# %%
confidence_level = 0.05
z_crit = st.norm.ppf(1-confidence_level/2)
E_Z = np.array([np.average(Z[0:i]) for i in range(len(Z))])
Z_ci = z_crit*np.array([st.sem(Z[0:i]) for i in range(len(Z))])

plt.figure(figsize = (14, 8))
plt.plot(range(len(Z)), E_Z, 
         'b', label='Mean Estimate')
plt.plot(range(len(Z)), E_Z - Z_ci, 
         'g', label='95% CI Lower Bound')
plt.plot(range(len(Z)), E_Z + Z_ci, 
         'r', label='95% CI Upper Bound')
plt.xlabel('Z')
plt.ylabel('Estimate of $\pi$')
plt.legend(loc='best')

print((E_Z - Z_ci)[-1], E_Z[-1], (E_Z + Z_ci)[-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:263: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims, where=where)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   subok=False)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 3.062222997728677 3.1631631631631634 3.26410332859765

# %% [markdown]
# **Part c**

# %%
X = np.random.random(1000)
Y = np.random.random(1000)
Z1 = []
for i in range(len(X)):
  if np.sqrt(X[i]**2 + Y[i]**2) <= 1 :
    Z1.append(4)
  else:
    Z1.append(0)
print(len(Z1))
# Out:
# 1000

# %%
Z2 = []
for i in range(len(X)):
  if np.sqrt((1-X[i])**2 + (1-Y[i])**2) <= 1 :
    Z2.append(4)
  else:
    Z2.append(0)

Z_a = [sum(i)/2 for i in zip(Z1, Z2)]

confidence_level = 0.05
z_crit = st.norm.ppf(1-confidence_level/2)

E_Z_a = np.array([np.average(Z_a[0:i]) for i in range(len(Z_a))])
Z_a_ci = z_crit*np.array([st.sem(Z_a[0:i]) for i in range(len(Z_a))])

plt.figure(figsize = (14, 8))
plt.plot(range(len(Z_a)), E_Z_a, 
         'b', label='Mean Estimate')
plt.plot(range(len(Z_a)), E_Z_a - Z_a_ci, 
         'g', label='95% CI Lower Bound')
plt.plot(range(len(Z_a)), E_Z_a + Z_a_ci, 
         'r', label='95% CI Upper Bound')
plt.xlabel('Z_a')
plt.ylabel('Estimate of $\pi$')
plt.legend(loc='best')

print((E_Z_a - Z_a_ci)[-1], E_Z_a[-1], (E_Z_a + Z_a_ci)[-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:263: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims, where=where)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   subok=False)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 3.055502504544813 3.1171171171171173 3.1787317296894213

# %% [markdown]
# # 3.2 Aircraft Range Estimation

# %% [markdown]
# **Part a**

# %%
rnd1 = np.random.random(1000)
rnd2 = np.random.random(1000)

V = 255
Isp = 5950
LD = 15 + (18-15) * np.sqrt(rnd1)
WiWf = 1.3 + (1.5 - 1.3) * np.sqrt(rnd2)

# %% [markdown]
# **Part b**

# %%
R = V*Isp*LD*np.log(WiWf)

# %% [markdown]
# **Part c**

# %% [markdown]
# i

# %%
fig = plt.figure(figsize = (14, 8))
R_km = R/1000
n, bins, patches = plt.hist(R_km, 11 , density=False, facecolor='g')

plt.title('histogram of the samples')
plt.xlabel("R")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ii

# %%
np.mean(R)/1000
# Out:
# 9227.63562199422

# %% [markdown]
# iii

# %%
R_sorted = np.sort(R)
R_sorted[249]/1000
# Out:
# 8563.792613908372

# %% [markdown]
# iv

# %%
np.count_nonzero(R > 9000000)/len(R)
# Out:
# 0.61

# %% [markdown]
# # 3.3 Sven’s Sweets
#
# **Part a)** D is a continous variable. Probability of D increases linearly by increaseing D between 40 and 70. Probability for D between 70 and 90 decrease. The min value of D is bigger than 39 and max value of D should be less 91.

# %%
fig = plt.figure(figsize = (14, 8))
x = [40,70,90]
y = [0,2/(90-40),0]
plt.plot(x, y)
plt.xlabel('Demand (D)')
plt.ylabel('probability')
plt.title('Demand Probability Density Function')
plt.show()

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# **Part b**

# %% [markdown]
# D : Costumer demand
#
# O : Order of Boxes of cookies
#
# P : Profit

# %% [markdown]
# Part c

# %% [markdown]
# Maximizing P (Profit)
#
# The funcytion of the profit is mentioned in part.

# %% [markdown]
# Part d

# %% [markdown]
# The CDF for D:
#
# \begin{cases}
#     0 & \text{for } D < 40, \\[2pt]
#     \frac{(D-40)^2}{(90-40)(70-40)} & \text{for } 40 \leq D \leq 70, \\[4pt]
#     1-\frac{(90-d)^2}{(90-40)(90-70)} & \text{for } 70 < D \leq 90, \\[4pt]
#     1 & \text{for } 90 < D.
# \end{cases}
#
#
#
# Given a random variate r drawn from the uniform distribution in the interval (0, 1), then the variate
#
# \begin{cases}
#     a+{\sqrt {r(b-a)(c-a)}}&{\text{ for }}0<r<F(c)\\&\\b-{\sqrt {(1-r)(b-a)(b-c)}}&{\text{ for }}F(c)\leq r<1
# \end{cases}
#
#
# where ${\displaystyle F(c)=(c-a)/(b-a).}$
#
# In this question, $a = 40, b = 90, and c = 70$. Then:
#
# ${\displaystyle F(70)=(70-40)/(90-40) = 0.6.}$

# %%
def demand(rand):
  if rand <= ((70-40)/(90-40)):
    D = 40 + np.round(np.sqrt(rand * (90-40) *(70 -40)))
  else:
    D = 90 - np.round(np.sqrt((1-rand) *(90 - 40) * (90-70)))
  return D

# %% [markdown]
# part e

# %%
def profit(O,D):
  if D >= O:
    P = (12-10) * O
  else:
    P = 12*D + 3 * (O - D) - 10 *O
  return P

# %% [markdown]
# Part f

# %%
r = np.random.random(10)
for ele in r:
  print(ele)
  O = 10*np.random.randint(1,20)
  D = demand(ele)
  print('Order is: ',O, "demand is: ", D,' and profit is: ',profit(O,D))
# Out:
# 0.6282942325267575
# Order is:  180 demand is:  71.0  and profit is:  -621.0
# 0.5902222135231285
# Order is:  110 demand is:  70.0  and profit is:  -140.0
# 0.8934986069682952
# Order is:  190 demand is:  80.0  and profit is:  -610.0
# 0.08509071564259574
# Order is:  110 demand is:  51.0  and profit is:  -311.0
# 0.22941702777560058
# Order is:  180 demand is:  59.0  and profit is:  -729.0
# 0.2578026686822451
# Order is:  70 demand is:  60.0  and profit is:  50.0
# 0.6708735274363525
# Order is:  10 demand is:  72.0  and profit is:  20
# 0.7627552649198241
# Order is:  100 demand is:  75.0  and profit is:  -25.0
# 0.7046587196361054
# Order is:  40 demand is:  73.0  and profit is:  80
# 0.20236113596524008
# Order is:  160 demand is:  57.0  and profit is:  -607.0

# %%
r = np.random.random(10000)
D_list = []
O_list = []
P_list = []

for ele in r:
  O = 10*np.random.randint(1,20)
  D = 60 #demand(ele)
  P = profit(O,D)
  O_list.append(O)Ω
  D_list.append(D)
  P_list.append(P)

optimal = np.argmax(P_list)
optimal
# Out:
# 3

# %%
ΩD_list[np.zzargmax(optimal)], O_list[np.argmax(optimal)], P_list[optimal]
# Out:
# (60, 190, 120)

# %%
fig = plt.figure(figsize = (14, 8))

ax = plt.axes(projection='3d')
ax.view_init(75, 0)
grid_points = [10*i for i in range(20)]
ax.yaxis.set_ticks(grid_points)
ax.set_xlabel("D")
ax.set_ylabel("O")
ax.set_zlabel("P")
plt.title("Profit based on the demand and order")
ax.plot_trisurf(D_list, O_list, P_list, cmap='viridis', edgecolor='none');
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-ed592f75b610> in <module>
#       9 ax.set_zlabel("P")
#      10 plt.title("Profit based on the demand and order")
# ---> 11 ax.plot_trisurf(D_list, O_list, P_list, cmap='viridis', edgecolor='none');
#
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot_trisurf(self, color, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1868
#    1869         tri, args, kwargs = \
# -> 1870             Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    1871         try:
#    1872             z = kwargs.pop('Z')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/tri/triangulation.py in get_from_args_and_kwargs(*args, **kwargs)
#     162             mask = kwargs.pop('mask', None)
#     163
# --> 164             triangulation = Triangulation(x, y, triangles, mask)
# ...

# %% [markdown]
# Based on the result shown in the plot and the mathematical relations between profit, demand, and order, demand must be determined when the amount of demand has been determined. In this case, you can smartly choose an amount for the demand leading to a higher profit. However, it seems that in this problem order also is a random variable. To ease of understanding and to have a close to real world situation, we geenrate the order as a uniform distribution (0,200). We believe that if we consider the damand at its max level, we have the better chance to have a good profit. In addition, if we have a demand close or equal to 90, and we have an order in range of 60 to 100, we can claim that we will have a good amount of profit. Also when demand and order amounts are close to eachother, we can have a pretty good profit.
